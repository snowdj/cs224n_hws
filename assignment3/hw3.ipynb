# %% [markdown]
# **Note**: I adapted the starter codes to make them compatible with python 3. All codes were run in python 3 (rather than the officially supported version of python, i.e., python 2) unless clarified.

# %% [markdown]
# ### Q1: A window into NER

# %% [markdown]
# **1a**. **i**. Example 1: "Lisa is coming." Lisa could be a person or a MISC named entity (the name of a hurricane).
#
# Example 2: "Genoa is beautiful." Genoa could be a MISC named entity (a city in Italy) or simply a noun (which refers to the headsail of a sailing vessel).

# %% [markdown]
# **ii**. To predict the named entity with ambiguous types, it could be helpful to use the context apart from the word itself. Sometimes named entities could be rare words; using features like casing could help.

# %% [markdown]
# **iii**. Parts of speech and casing.

# %% [markdown]
# **1b**. **i**. $e^{(t)}$ is $1 \times (2w+1)D$; $W$ is $(2w+1) \times H$; $U$ is $H \times C$.

# %% [markdown]
# **ii**. The computational complexity is $O((2w+1)DHT + HCT)$.

# %% [markdown]
# **1c**. **i**.

# %%
# %%bash
# source activate py36
# python q1_window.py test1
# Out:
# INFO:Testing make_windowed_data
# INFO:Passed!

# %% [markdown]
# **ii**.

# %%
# %%bash
# source activate py36
# python q1_window.py test2
# Out:
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
#
# ...
# 5/5 [==============================] - 0s
# INFO:Testing implementation of WindowModel
# INFO:Loading training data...
# INFO:Done. Read 721 sentences
# INFO:Loading dev data...
# INFO:Done. Read 721 sentences
# INFO:Built dictionary for 2653 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 1.48 seconds
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	261.00 	3.00   	6.00   	0.00   	554.00
# ORG    	65.00  	0.00   	8.00   	0.00   	318.00
# ...

# %% [markdown]
# **iii** and **iv**.

# %%
# %%bash
# source activate py36
# python q1_window.py train
# Out:
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# ...
# 26/26 [==============================] - 0s
#
# 26/26 [==============================] - 0s
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 1.66 seconds
# INFO:Epoch 1 out of 10
# INFO:Evaluating on development data
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2713.00 	191.00  	73.00   	13.00   	159.00
# ...

# %% [markdown]
# **1d**. **i**. See above for the results. Confusion matrix shows many errors are made on organizations, where many are confused for people or missed out. And people are well recognized.

# %% [markdown]
# **ii**. The window-based model can't use information from neighboring predictions to disambiguate labeling decisions, leading to non-contiguous entity predictions.
#
# The window-based model can't use information from other parts of the sentence.
